# %%
from simple_spotify.api import Spotify
from simple_spotify.authorization import ClientCredentialsFlow
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from googlesearch import search, search_news

import nltk
# nltk.download('all')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.linear_model import LogisticRegressionCV
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('./african_crises.csv')

# %%
df.shape
# Out:
# (1059, 14)

# %%
df.pair

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_eeb49d40_1555_11ea_aba6_406c8f31aef1row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_eeb49d40_1555_11ea_aba6_406c8f31aef1row0_col1 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_eeb49d40_1555_11ea_aba6_406c8f31aef1row0_col2 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_eeb49d40_1555_11ea_aba6_406c8f31aef1row0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_eeb49d40_1555_11ea_aba6_406c8f31aef1row0_col4 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_eeb49d40_1555_11ea_aba6_406c8f31aef1row0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_eeb49d40_1555_11ea_aba6_406c8f31aef1row0_col6 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
# ...

# %%
df.columns
# Out:
# Index(['case', 'cc3', 'country', 'year', 'systemic_crisis', 'exch_usd',
#        'domestic_debt_in_default', 'sovereign_external_debt_default',
#        'gdp_weighted_default', 'inflation_annual_cpi', 'independence',
#        'currency_crises', 'inflation_crises', 'banking_crisis'],
#       dtype='object')

# %%
df_rates = df.groupby(['cc3','exch_usd'])['exch_usd']   #df['D'] = df.groupby(['A','B'])['C']

# %%
df_range = df.groupby(['cc3'])['inflation_annual_cpi'].max() - df.groupby(['cc3'])['inflation_annual_cpi'].min()

# %%
df_range.sort_values()
# Out:
# cc3
# CIV    2.912504e+01
# CAF    3.652306e+01
# MUS    4.213091e+01
# KEN    4.626472e+01
# ZAF    5.326057e+01
# MAR    5.964420e+01
# EGY    6.926852e+01
# NGA    7.728205e+01
# TUN    8.037370e+01
# DZA    9.015495e+01
# ZMB    1.837114e+02
# AGO    4.173189e+03
# ZWE    2.198971e+07
# Name: inflation_annual_cpi, dtype: float64

# %%
df.groupby(by=['cc3'])['exch_usd']

# %%
df[df['cc3'] == 'CIV']
# Out:
#      case  cc3      country  year  systemic_crisis  exch_usd  \
# 220    15  CIV  Ivory Coast  1952                0       0.0
# 221    15  CIV  Ivory Coast  1953                0       0.0
# 222    15  CIV  Ivory Coast  1954                0       0.0
# 223    15  CIV  Ivory Coast  1955                0       0.0
# 224    15  CIV  Ivory Coast  1956                0       0.0
# ..    ...  ...          ...   ...              ...       ...
# 278    15  CIV  Ivory Coast  2010                0       0.0
# 279    15  CIV  Ivory Coast  2011                0       0.0
# 280    15  CIV  Ivory Coast  2012                0       0.0
# 281    15  CIV  Ivory Coast  2013                0       0.0
# 282    15  CIV  Ivory Coast  2014                0       0.0
#
#      domestic_debt_in_default  sovereign_external_debt_default  \
# 220                         0                                0
# 221                         0                                0
# ...
